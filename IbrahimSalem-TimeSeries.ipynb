# %% [markdown]
# # Time Series Forecasting Exam
#
# In this exam, you will work on a time series forecasting task. The goal is to go through the entire workflow from loading the data to evaluating the model and making predictions. Follow each step carefully. The dataset is stored in you can access it [here](https://www.kaggle.com/datasets/khaledzsa/traffic-dataset), the target is to predict `traffic_volume` column. There is also command to download the dataset below.
#
# ## Dataset: Traffic Dataset
#
# ### Dataset Overview:
#
# - **Name**: Traffic Dataset
# - **Description**: This dataset contains hourly data on the traffic volume for westbound I-94, a major interstate highway in the US that connects Minneapolis and St Paul, Minnesota. The data was collected by the Minnesota Department of Transportation (MnDOT) from 2012 to 2018 at a station roughly midway between the two cities.
# - **Time Period**: Starting from 18-11-2016
# - **Frequency**: Hourly observations
#
# ### Features:
#
# 1. **temp:** a numeric variable that shows the average temperature in kelvin.
# 2. **rain_1h:** a numeric variable that shows the amount of rain in mm that occurred in the hour.
# 3. **snow_1h:** a numeric variable that shows the amount of snow in mm that occurred in the hour.
# 4. **clouds_all:** a numeric variable that shows the percentage of cloud cover.
# 5. **weather_main:** a categorical variable that gives a short textual description of the current weather (such as Clear, Clouds, Rain, etc.).
# 6. **weather_description:** a categorical variable that gives a longer textual description of the current weather (such as light rain, overcast clouds, etc.).
# 7. **date_time:** a datetime variable that shows the hour of the data collected in local CST time.
# 8. **traffic_volume:** a numeric variable that shows the hourly I-94 reported westbound traffic volume.
#
# #### Feel free to add or rearrange steps as you see fit to optimize your workflow. One additional note: the model's performance doesn't need to be 100% accurate. Instead, focus on achieving the best possible results while balancing performance and generalization.

# %% [markdown]
# ## Load the Data
#
# Load the time series dataset into a pandas DataFrame.
#
# **Instructions:**
# - Use `pandas` to load your dataset.
# - Display the first few rows to understand its structure.
# - Make sure the datetime column is correctly parsed.

# %%
"""# Here is a helping code that will download and unzip the dataset for you.
# Once you download the dataset you may comment the code!
# !kaggle datasets download -d khaledzsa/traffic-dataset
# !unzip traffic-dataset.zip"""
# Out:
# '# Here is a helping code that will download and unzip the dataset for you.\n# Once you download the dataset you may comment the code!\n!kaggle datasets download -d khaledzsa/traffic-dataset\n!unzip traffic-dataset.zip'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/Traffic Data.csv', parse_dates=['date_time'], index_col='date_time')

# %%
df.head()
# Out:
#                      traffic_volume    temp  rain_1h  snow_1h  clouds_all  \
# date_time
# 2017-08-27 01:00:00          1209.0  291.15      0.0      0.0          90
# 2018-09-06 23:00:00          1248.0  286.01      0.0      0.0           1
# 2017-08-25 18:00:00          4602.0  293.69      0.0      0.0          75
# 2017-11-09 22:00:00          2838.0  262.35      0.0      0.0           1
# 2017-11-09 15:00:00          5794.0  267.08      0.0      0.0           5
#
#                     weather_main weather_description
# date_time
# 2017-08-27 01:00:00         Mist                mist
# 2018-09-06 23:00:00        Clear        sky is clear
# 2017-08-25 18:00:00       Clouds       broken clouds
# 2017-11-09 22:00:00        Clear        sky is clear
# 2017-11-09 15:00:00        Clear        sky is clear

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 20000 entries, 2017-08-27 01:00:00 to 2018-05-31 18:00:00
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   traffic_volume       19980 non-null  float64
#  1   temp                 20000 non-null  float64
#  2   rain_1h              20000 non-null  float64
#  3   snow_1h              20000 non-null  float64
#  4   clouds_all           20000 non-null  int64
#  5   weather_main         20000 non-null  object
#  6   weather_description  20000 non-null  object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 1.2+ MB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# Perform exploratory data analysis on the dataset.
#
# **Instructions:**
# - Plot the time series data.
# - Analyze trends, seasonality, and potential outliers.
# - Plot boxplots or scatter plots to identify any outliers or anomalies in the data.
# - Seasonal Decomposition: Use `seasonal_decompose` from the `statsmodels` library to break down the time series data into trend, seasonality, and residual components. Analyze each component to gain insights into the long-term movement (trend), regular patterns (seasonality), and remaining fluctuations (residuals).
#
# Do more if needed!

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['traffic_volume'])
plt.title('Traffic Volume Time Series')
plt.xlabel('Date')
plt.ylabel('Traffic Volume')
plt.show()

# %%
df_D = df.resample('D').sum()

# %%
plt.figure(figsize=(20, 10))
plt.plot(df_D.index, df_D['traffic_volume'])
plt.title('Traffic Volume Time Series')
plt.xlabel('Date')
plt.ylabel('Traffic Volume')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df_D['traffic_volume'])
plt.title('Box Plot of Traffic Volume')
plt.ylabel('Traffic Volume')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df_D.index,df_D['traffic_volume'])
plt.title('Box Plot of Traffic Volume')
plt.ylabel('Traffic Volume')
plt.show()

# %% [markdown]
# ## Data Preprocessing
#
# Clean and preprocess the data.
#
# **Instructions:**
# - Handle any missing values in the dataset.
# - If necessary, resample the data to ensure consistent time intervals.
# - Create any additional features needed, such as lags or moving averages.
# - Make sure that the dates are sorted correctly.
#
# Do more if needed!

# %%
df.isnull().sum()
# Out:
# traffic_volume         20
# temp                    0
# rain_1h                 0
# snow_1h                 0
# clouds_all              0
# weather_main            0
# weather_description     0
# dtype: int64

# %%
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    return  df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# %%
df1=remove_outliers(df_D,'traffic_volume')

# %%
df1['traffic_volume'].fillna(method='ffill', inplace=True)

# %%
df1.index.sort_values()
# Out:
# DatetimeIndex(['2016-11-18', '2016-11-19', '2016-11-20', '2016-11-21',
#                '2016-11-24', '2016-11-25', '2016-11-26', '2016-11-27',
#                '2016-11-29', '2016-12-01',
#                ...
#                '2018-09-21', '2018-09-22', '2018-09-23', '2018-09-24',
#                '2018-09-25', '2018-09-26', '2018-09-27', '2018-09-28',
#                '2018-09-29', '2018-09-30'],
#               dtype='datetime64[ns]', name='date_time', length=615, freq=None)

# %%
df1.index
# Out:
# DatetimeIndex(['2016-11-18', '2016-11-19', '2016-11-20', '2016-11-21',
#                '2016-11-24', '2016-11-25', '2016-11-26', '2016-11-27',
#                '2016-11-29', '2016-12-01',
#                ...
#                '2018-09-21', '2018-09-22', '2018-09-23', '2018-09-24',
#                '2018-09-25', '2018-09-26', '2018-09-27', '2018-09-28',
#                '2018-09-29', '2018-09-30'],
#               dtype='datetime64[ns]', name='date_time', length=615, freq=None)

# %%
import statsmodels.api as sm

res=sm.tsa.seasonal_decompose(df1['traffic_volume'], model='additive', period=(7))

# %% [markdown]
# ## Feature Engineering
#
# ### Instructions:
#
# - **Shift Method**: Use the `shift` method to create a new column `prev_traffic_volume`, which represents the previous day's traffic volume.
#
# - **Difference between traffic_volume**: Calculate the difference between the values in `traffic_volume` column to highlight short-term volume.
#
# - **Date Features**: Extract meaningful time-based features from the `date_time` column to enhance the model's ability to detect temporal patterns. These features include:
#   - **Day of the week**: To capture weekly seasonality.
#   - **Month**: To capture monthly trends.
#   - **Day of the year**: Useful for modeling yearly seasonality.

# %%
df1.head()
# Out:
#             traffic_volume      temp  rain_1h  snow_1h  clouds_all  \
# date_time
# 2016-11-18         67940.0   5471.65      0.0      0.0        1700
# 2016-11-19         65048.0   6505.16      0.0      0.0        1288
# 2016-11-20         53556.0   6469.56      0.0      0.0         876
# 2016-11-21         78376.0   6519.71      0.0      0.0         145
# 2016-11-24         93206.0  11528.86      0.0      0.0        3765
#
#                                                  weather_main  \
# date_time
# 2016-11-18  FogSnowMistMistFogSnowMistFogSnowSnowMistMistS...
# 2016-11-19  CloudsHazeHazeCloudsCloudsCloudsCloudsSnowSnow...
# 2016-11-20  ClearClearClearClearCloudsCloudsClearCloudsClo...
# 2016-11-21  CloudsClearClearClearClearClearClearClearClear...
# 2016-11-24  MistMistMistMistMistMistMistFogMistMistMistMis...
#
#                                           weather_description
# date_time
# 2016-11-18  fogheavy snowmistmistfogheavy snowmistfogheavy...
# 2016-11-19  overcast cloudshazehazeovercast cloudsovercast...
# 2016-11-20  sky is clearsky is clearsky is clearsky is cle...
# 2016-11-21  scattered cloudssky is clearsky is clearsky is...
# 2016-11-24  mistmistmistmistmistmistmistfogmistmistmistmis...

# %%
df2=df1.copy()
df2['prev_traffic_volume']=df2['traffic_volume'].shift(1)
df2 = df2.dropna()


df2.head()
# Out:
#             traffic_volume      temp  rain_1h  snow_1h  clouds_all  \
# date_time
# 2016-11-19         65048.0   6505.16      0.0      0.0        1288
# 2016-11-20         53556.0   6469.56      0.0      0.0         876
# 2016-11-21         78376.0   6519.71      0.0      0.0         145
# 2016-11-24         93206.0  11528.86      0.0      0.0        3765
# 2016-11-25         60339.0   8228.92      0.0      0.0        2403
#
#                                                  weather_main  \
# date_time
# 2016-11-19  CloudsHazeHazeCloudsCloudsCloudsCloudsSnowSnow...
# 2016-11-20  ClearClearClearClearCloudsCloudsClearCloudsClo...
# 2016-11-21  CloudsClearClearClearClearClearClearClearClear...
# 2016-11-24  MistMistMistMistMistMistMistFogMistMistMistMis...
# 2016-11-25  SnowMistMistSnowMistSnowSnowMistSnowMistMistMi...
#
#                                           weather_description  \
# date_time
# 2016-11-19  overcast cloudshazehazeovercast cloudsovercast...
# 2016-11-20  sky is clearsky is clearsky is clearsky is cle...
# 2016-11-21  scattered cloudssky is clearsky is clearsky is...
# 2016-11-24  mistmistmistmistmistmistmistfogmistmistmistmis...
# 2016-11-25  light snowmistmistlight snowmistlight snowligh...
#
#             prev_traffic_volume
# date_time
# 2016-11-19              67940.0
# 2016-11-20              65048.0
# 2016-11-21              53556.0
# 2016-11-24              78376.0
# 2016-11-25              93206.0

# %%
df1.head()
# Out:
#             traffic_volume      temp  rain_1h  snow_1h  clouds_all  \
# date_time
# 2016-11-18         67940.0   5471.65      0.0      0.0        1700
# 2016-11-19         65048.0   6505.16      0.0      0.0        1288
# 2016-11-20         53556.0   6469.56      0.0      0.0         876
# 2016-11-21         78376.0   6519.71      0.0      0.0         145
# 2016-11-24         93206.0  11528.86      0.0      0.0        3765
#
#                                                  weather_main  \
# date_time
# 2016-11-18  FogSnowMistMistFogSnowMistFogSnowSnowMistMistS...
# 2016-11-19  CloudsHazeHazeCloudsCloudsCloudsCloudsSnowSnow...
# 2016-11-20  ClearClearClearClearCloudsCloudsClearCloudsClo...
# 2016-11-21  CloudsClearClearClearClearClearClearClearClear...
# 2016-11-24  MistMistMistMistMistMistMistFogMistMistMistMis...
#
#                                           weather_description
# date_time
# 2016-11-18  fogheavy snowmistmistfogheavy snowmistfogheavy...
# 2016-11-19  overcast cloudshazehazeovercast cloudsovercast...
# 2016-11-20  sky is clearsky is clearsky is clearsky is cle...
# 2016-11-21  scattered cloudssky is clearsky is clearsky is...
# 2016-11-24  mistmistmistmistmistmistmistfogmistmistmistmis...

# %%
df2['traffic_volume_diff'] = df2['traffic_volume'].diff()
df2 = df2.dropna()

# %%
df2['month']=df2.index.month

# %%
df2['year']=df2.index.year
df2['weekly']=df2.index.isocalendar().week

# %% [markdown]
# ## Train-Test Split
#
# Split the dataset into training and testing sets.
#
# **Instructions:**
# - Ensure the split maintains the time order of the data.
# - Decide on an appropriate ratio for splitting the data.

# %%
def create_sequence(df,lookback=10):
  X=[]
  y=[]
  for i in range(len(df) - lookback):
        end_ix = i + lookback
        X.append(df[i:end_ix])
        y.append(df[end_ix])

  return np.array(X),np.array(y)

# %%
df2=df2.drop(columns=['weather_main','weather_description'])

# %%
df2.isnull().sum()
# Out:
# traffic_volume         0
# temp                   0
# rain_1h                0
# snow_1h                0
# clouds_all             0
# prev_traffic_volume    0
# traffic_volume_diff    0
# month                  0
# year                   0
# weekly                 0
# dtype: int64

# %%
df5=df2
df5=df5.values

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
df5_scaled = scaler.fit_transform(df5.reshape(-1, 1))

# %%
lookback = 3
X, y = create_sequence(df5_scaled, lookback)

# %%
df2.head()
# Out:
#             traffic_volume      temp  rain_1h  snow_1h  clouds_all  \
# date_time
# 2016-11-20         53556.0   6469.56      0.0      0.0         876
# 2016-11-21         78376.0   6519.71      0.0      0.0         145
# 2016-11-24         93206.0  11528.86      0.0      0.0        3765
# 2016-11-25         60339.0   8228.92      0.0      0.0        2403
# 2016-11-26         73574.0  10398.42      0.0      0.0         365
#
#             prev_traffic_volume  traffic_volume_diff  month  year  weekly
# date_time
# 2016-11-20              65048.0             -11492.0     11  2016      46
# 2016-11-21              53556.0              24820.0     11  2016      47
# 2016-11-24              78376.0              14830.0     11  2016      47
# 2016-11-25              93206.0             -32867.0     11  2016      47
# 2016-11-26              60339.0              13235.0     11  2016      47

# %%
train_size = int(len(df2) * 0.75)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
print(np.isnan(X_train).sum(), np.isnan(y_train).sum())
print(np.isnan(X_test).sum(), np.isnan(y_test).sum())
# Out:
# 0 0
# 0 0

# %% [markdown]
# ## Feature Scaling
#
# Apply feature scaling to the data if needed.
#
# **Instructions:**
# - Use a scaling method such as MinMaxScaler or StandardScaler.
# - Ensure scaling is applied correctly to both training and testing data.

# %%
#MinMax applied up splitting data

# %% [markdown]
# ## Models Selection
#
# Choose two models for time series forecasting.
#
# **Instructions:**
# - Select two models such as ARIMA, SARIMA, RNN, LSTM, or GRU.
# - Train these models and then compare their performance.

# %%
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.models import Sequential
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.LSTM(50, return_sequences=True, input_shape=(X_train.shape[1],X_train.shape[2])),
    tf.keras.layers.LSTM(50),
    tf.keras.layers.Dense(1)
])

# %%
model.compile(optimizer='adam', loss='mse')

# %% [markdown]
# ### Model 1 Training
#
# Train your first model on the training dataset.
#
# **Instructions:**
# - Fit the first model to the training data.
# - Ensure to monitor the training process.

# %%
history=model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - loss: 0.0334 - val_loss: 0.0325
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0284 - val_loss: 0.0318
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0306 - val_loss: 0.0310
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0290 - val_loss: 0.0298
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0258 - val_loss: 0.0285
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0293 - val_loss: 0.0287
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0237 - val_loss: 0.0262
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0242 - val_loss: 0.0260
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0269 - val_loss: 0.0264
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0231 - val_loss: 0.0244
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0212 - val_loss: 0.0245
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0218 - val_loss: 0.0246
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0249 - val_loss: 0.0240
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0232 - val_loss: 0.0246
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0246 - val_loss: 0.0237
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0240 - val_loss: 0.0242
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0232 - val_loss: 0.0230
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0213 - val_loss: 0.0230
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0223 - val_loss: 0.0233
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0232 - val_loss: 0.0226
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0209 - val_loss: 0.0227
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0241 - val_loss: 0.0230
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0200 - val_loss: 0.0227
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0232 - val_loss: 0.0221
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0228 - val_loss: 0.0219
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0224 - val_loss: 0.0217
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0209 - val_loss: 0.0216
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0211 - val_loss: 0.0216
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0195 - val_loss: 0.0220
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0209 - val_loss: 0.0223
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0211 - val_loss: 0.0211
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0187 - val_loss: 0.0216
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0201 - val_loss: 0.0209
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0214 - val_loss: 0.0213
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0202 - val_loss: 0.0211
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0192 - val_loss: 0.0207
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0205 - val_loss: 0.0206
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0211 - val_loss: 0.0207
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0182 - val_loss: 0.0205
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0194 - val_loss: 0.0208
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0206 - val_loss: 0.0205
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0197 - val_loss: 0.0206
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0187 - val_loss: 0.0216
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0200 - val_loss: 0.0222
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0209 - val_loss: 0.0207
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0208 - val_loss: 0.0204
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0186 - val_loss: 0.0210
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0203 - val_loss: 0.0206
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0186 - val_loss: 0.0209
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0225 - val_loss: 0.0205
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0201 - val_loss: 0.0216
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0209 - val_loss: 0.0204
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0195 - val_loss: 0.0203
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0204 - val_loss: 0.0204
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0192 - val_loss: 0.0206
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0186 - val_loss: 0.0204
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0197 - val_loss: 0.0204
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0192 - val_loss: 0.0204
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0191 - val_loss: 0.0214
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0194 - val_loss: 0.0213
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0193 - val_loss: 0.0204
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0200 - val_loss: 0.0203
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0216 - val_loss: 0.0216
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0219 - val_loss: 0.0230
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0244 - val_loss: 0.0217
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0188 - val_loss: 0.0205
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0199 - val_loss: 0.0203
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0199 - val_loss: 0.0203
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0195 - val_loss: 0.0205
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0191 - val_loss: 0.0204
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0195 - val_loss: 0.0207
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0208 - val_loss: 0.0206
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0184 - val_loss: 0.0205
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0183 - val_loss: 0.0208
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0191 - val_loss: 0.0208
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0205 - val_loss: 0.0206
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0178 - val_loss: 0.0204
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0207 - val_loss: 0.0204
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0200 - val_loss: 0.0203
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0189 - val_loss: 0.0207
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0187 - val_loss: 0.0204
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0197 - val_loss: 0.0205
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0187 - val_loss: 0.0202
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0184 - val_loss: 0.0206
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0188 - val_loss: 0.0206
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0182 - val_loss: 0.0205
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0194 - val_loss: 0.0202
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0203 - val_loss: 0.0205
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0203 - val_loss: 0.0211
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0217 - val_loss: 0.0202
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0225 - val_loss: 0.0202
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0200 - val_loss: 0.0202
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0194 - val_loss: 0.0205
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0190 - val_loss: 0.0202
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0197 - val_loss: 0.0204
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0196 - val_loss: 0.0202
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0199 - val_loss: 0.0202
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0204 - val_loss: 0.0205
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0182 - val_loss: 0.0202
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0202 - val_loss: 0.0202

# %% [markdown]
# ### Make 1 Predictions
#
# Generate predictions on the test dataset.
#
# ### Instructions:
# - Use the trained model to make predictions on the test data.
# - Store the predictions for further analysis.

# %%
y_pred = model.predict(X_test)
y_pred = scaler.inverse_transform(y_pred)
# Out:
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %% [markdown]
# ### Model 1 Evaluation
#
# Evaluate the performance of your first model on the test dataset.
#
# **Instructions:**
# - Calculate evaluation metrics such as MAE, MSE, RMSE, or MAPE.
# - Plot the predicted vs actual values for the test set.
# - Plot the loss and the validation loss.

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)

# %%
print('mse',mse)
print('rmse',rmse)
print(mae)
# Out:
# mse 777397066.0943632
# rmse 27881.84115323741
# 20915.95294908138

# %% [markdown]
# ### Model 2 Training
#
# Train your second model on the training dataset.
#
# **Instructions:**
# - Fit the second model to the training data.
# - Ensure to monitor the training process.

# %%
model_gru = tf.keras.Sequential([
    tf.keras.layers.GRU(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    tf.keras.layers.GRU(50),
    tf.keras.layers.Dense(1)
])
model_gru.compile(optimizer='adam', loss='mse')

# %%
history2= model_gru.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1
)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 0.2072 - val_loss: 0.0374
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0389 - val_loss: 0.0378
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0342 - val_loss: 0.0368
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0334 - val_loss: 0.0354
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0322 - val_loss: 0.0345
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0358 - val_loss: 0.0335
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0318 - val_loss: 0.0328
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0331 - val_loss: 0.0319
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0314 - val_loss: 0.0310
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0302 - val_loss: 0.0300
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0310 - val_loss: 0.0293
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0269 - val_loss: 0.0276
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0237 - val_loss: 0.0262
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0261 - val_loss: 0.0254
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0237 - val_loss: 0.0233
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0249 - val_loss: 0.0222
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0218 - val_loss: 0.0218
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0202 - val_loss: 0.0218
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0198 - val_loss: 0.0215
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0204 - val_loss: 0.0211
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0186 - val_loss: 0.0210
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0190 - val_loss: 0.0207
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0198 - val_loss: 0.0210
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0215 - val_loss: 0.0208
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0209 - val_loss: 0.0205
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0199 - val_loss: 0.0210
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0194 - val_loss: 0.0205
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0201 - val_loss: 0.0206
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0210 - val_loss: 0.0207
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0205 - val_loss: 0.0231
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0210 - val_loss: 0.0209
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0208 - val_loss: 0.0208
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0186 - val_loss: 0.0215
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0215 - val_loss: 0.0204
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0175 - val_loss: 0.0209
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0191 - val_loss: 0.0204
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0205 - val_loss: 0.0227
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0219 - val_loss: 0.0218
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0181 - val_loss: 0.0223
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0197 - val_loss: 0.0203
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0207 - val_loss: 0.0208
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0194 - val_loss: 0.0206
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0192 - val_loss: 0.0209
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0195 - val_loss: 0.0204
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0189 - val_loss: 0.0226
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0213 - val_loss: 0.0208
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0211 - val_loss: 0.0216
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0223 - val_loss: 0.0203
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0176 - val_loss: 0.0206
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0199 - val_loss: 0.0203
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0192 - val_loss: 0.0203
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0213 - val_loss: 0.0211
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0201 - val_loss: 0.0212
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0191 - val_loss: 0.0207
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0207 - val_loss: 0.0206
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0195 - val_loss: 0.0203
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0201 - val_loss: 0.0244
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0216 - val_loss: 0.0217
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0210 - val_loss: 0.0203
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0203 - val_loss: 0.0216
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0205 - val_loss: 0.0234
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0235 - val_loss: 0.0219
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0214 - val_loss: 0.0204
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0221 - val_loss: 0.0207
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0193 - val_loss: 0.0204
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0185 - val_loss: 0.0205
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0188 - val_loss: 0.0204
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0189 - val_loss: 0.0224
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0237 - val_loss: 0.0206
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0189 - val_loss: 0.0203
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0188 - val_loss: 0.0203
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0207 - val_loss: 0.0206
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0217 - val_loss: 0.0217
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0206 - val_loss: 0.0205
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0198 - val_loss: 0.0210
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0177 - val_loss: 0.0222
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0197 - val_loss: 0.0207
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0205 - val_loss: 0.0214
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0223 - val_loss: 0.0214
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0199 - val_loss: 0.0206
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0191 - val_loss: 0.0203
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0198 - val_loss: 0.0203
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0186 - val_loss: 0.0203
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0208 - val_loss: 0.0204
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0192 - val_loss: 0.0209
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0199 - val_loss: 0.0204
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0184 - val_loss: 0.0203
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0182 - val_loss: 0.0210
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0205 - val_loss: 0.0203
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0205 - val_loss: 0.0215
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0226 - val_loss: 0.0206
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0208 - val_loss: 0.0210
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0179 - val_loss: 0.0202
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0201 - val_loss: 0.0202
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0211 - val_loss: 0.0205
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0188 - val_loss: 0.0221
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0210 - val_loss: 0.0205
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0176 - val_loss: 0.0204
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0218 - val_loss: 0.0202
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0205 - val_loss: 0.0205

# %% [markdown]
# ### Make 2 Predictions
#
# Generate predictions on the test dataset.
#
# ### Instructions:
# - Use the trained model to make predictions on the test data.
# - Store the predictions for further analysis.

# %%
y_pred_gru = model_gru.predict(X_test)
y_pred_gru = scaler.inverse_transform(y_pred_gru)
# Out:
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

# %% [markdown]
# ### Model 2 Evaluation
#
# Evaluate the performance of your second model on the test dataset.
#
# **Instructions:**
# - Calculate evaluation metrics such as MAE, MSE, RMSE, or MAPE.
# - Plot the predicted vs actual values for the test set.
# - Plot the loss and the validation loss.

# %%
mse_gru = mean_squared_error(y_test, y_pred_gru)
mae_gru = mean_absolute_error(y_test, y_pred_gru)
rmse_gru = np.sqrt(mse_gru)

print('mse',mse_gru)
print('mae',mae_gru)
print('rmse',rmse_gru)
# Out:
# mse 904641467.9223695
# mae 22637.72165901399
# rmse 30077.258317911383

# %% [markdown]
# ## Project Questions:
#
# 1. **Data Preprocessing**: Explain why you chose your specific data preprocessing techniques (e.g., normalization, handling missing values). How did these techniques help prepare the data for training the model?
# 2. **Feature Engineering**: Did you perform any feature engineering or transformations? Describe your decisions and how these new features (or transformed features) contributed to the forecasting model.
# 3. **Model Architecture**: Describe the reasoning behind your model’s architecture (e.g., the type of model, layers, number of neurons, and activation functions). Why did you believe this architecture was appropriate for time series forecasting?
# 4. **Training Process**: Discuss why you chose your batch size, number of epochs, and optimizer. How did these choices affect the training process? Did you experiment with different values, and what were the outcomes?
# 5. **Loss Function and Metrics**: Why did you choose the specific loss function and evaluation metrics (e.g., MAE, RMSE, MAPE)? How do they align with the objective of forecasting?
# 6. **Model Tuning (If Done)**: Describe any tuning you performed (e.g., hyperparameter tuning) and why you felt it was necessary. How did these adjustments improve model performance?
# 7. **Overfitting and Underfitting**: Analyze whether the model encountered any overfitting or underfitting during training. What strategies could you implement to mitigate these issues?
# 8. **Future Improvements**: Suggest potential improvements or further steps you could take to enhance model performance. Consider using different algorithms, feature engineering techniques, or tuning hyperparameters.

# %% [markdown]
# ### Answer Here:
